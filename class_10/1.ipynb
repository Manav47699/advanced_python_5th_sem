# %% [markdown]
# # Covavarience

# %%
print ("hi")
# Out:
# hi

# %%
import numpy as np
import pandas as pd

x = np.array([10, 20, 30])
y = np.array([30, 20, 10])

np.cov(x,y)         #covaiance bhane relation between 2 or more varibales.

# df = pd.DataFrame({"X":x, "Y":y})
# df.cov()
# Out:
# array([[ 100., -100.],
#        [-100.,  100.]])

# %%
df = pd.DataFrame({"X":x, "Y":y})
df.cov()
# Out:
#        X      Y
# X  100.0 -100.0
# Y -100.0  100.0

# %%
np.corrcoef(x, y)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
df.corr()
# Out:
#      X    Y
# X  1.0 -1.0
# Y -1.0  1.0

# %%
import seaborn as sns
from sklearn.datasets import load_iris        

x, y = load_iris(as_frame=True, return_X_y=True)

# %%
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
sns.heatmap(x.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Skewness
# - zero
# - positive/right
# - negative/left

# %%
a = np.array([10, 20, 200])
b = np.array([20, 30, 40])

df = pd.DataFrame({"A":a, "B":b})

# %%
print ("skweness of X column", df["A"].skew())
print ("skewness of Y column", df["B"].skew())
# Out:
# skweness of X column 1.7150235688268123
# skewness of Y column 0.0

# %%
#kurtosis (measuers the tailedness)
# - mesokurtic ->
# - leptokutic -> 
# - platylocutic ->
# Random variable -> 
a = np.array([10, 20,30, 200])
b = np.array([20, 30,50, 40])

df = pd.DataFrame({"A":a, "B":b})
print("kurtosis of A coulmn", df["A"].kurt())
print("kurtosis of B coulmn", df["B"].kurt())
# Out:
# kurtosis of A coulmn 3.8379008746355687
# kurtosis of B coulmn -1.1999999999999993
