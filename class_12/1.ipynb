# %% [markdown]
# # data visualization

# %%
print ("hi")
# Out:
# hi

# %%
import pandas as pd

df = pd.read_csv("tips.csv")
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['day'].value_counts(normalize=True)
# Out:
# day
# Sat     0.356557
# Sun     0.311475
# Thur    0.254098
# Fri     0.077869
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar(x = df['day'].unique(), height=df['day'].value_counts(), color=["red","blue", "green", "pink"])
plt.show()

# %%
# plt.hist(x = df['day'].unique(), height=df['day'].value_counts())
import seaborn as sns
plt.figure(figsize=(8, 4))
sns.histplot(df['total_bill'], kde = True)
plt.show()

# %%
sns.boxplot(x='day', y = 'total_bill', data=df)
plt.title("total bill box plot")
plt.show()

# %%
sns.boxplot(x='gender', y = 'tip', data=df)
plt.title("total bill box plot")
plt.show()

# %%
sns.scatterplot(x= 'total_bill', y='tip', hue='gender', data=df)
plt.title("Total Bill VS Tip")
plt.show()

# %%
corr_mat = df.select_dtypes(include="number").corr()
sns.heatmap(corr_mat, annot = True, cmap='coolwarm')
plt.title("correlation heatmap")
plt.show()

# %% [markdown]
# # inferential statistics

# %%
from scipy.stats import chi2_contingency

# %%
contingency_table = pd.crosstab(df['gender'], df['smoker'])
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)
print (f"chi_2:{chi2}, ,p_value:{p}")
print(contingency_table)
# Out:
# chi_2:0.0, ,p_value:1.0
# smoker  No  Yes
# gender
# Female  54   33
# Male    97   60

# %% [markdown]
# # what is pair plot??
# -> A pair plot is a graphical representation of the relationship between
# every possible pair of variables in a multivariate dataset, typically
# displayed as a matrix of scatter plots.

# %%
sns.pairplot(df, hue='gender')
plt.show()

# %% [markdown]
# EDA automation, y data profiling
