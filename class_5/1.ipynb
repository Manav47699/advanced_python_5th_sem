# %%
#open weather map ma gayera euta api दर्ता गर्नुहोस्
# what is rest and soap(simple object acess protocol)
#soap is only used in specific places only, eg -> banks

# - mongodb ma jane
# - atlas ma jane
# - new project ma click garne sign in garera
# - project ko naam iyera next garne
# - create cluster ma jane, free tire choose garne
# - create deployment ma jane, connect to Cluster ma jane, form barne
# - connect your application ma jane, driver/language ra version choose garne, andi url copy garne
# -

# %%
print ("hellow")
# Out:
# hellow

# %%
from pymongo import MongoClient
client = MongoClient("")
db = client("school")
collection = db["student"]

# %%
# !pip install requests

# %%
import requests
from pprint import pprint
url = "https://jsonplaceholder.typicode.com/posts/1"

# %%
response = requests.get(url)
print(response)
print(type(response))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %%
if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print ("Error: ", response.status_code)
# Out:
# {'body': 'quia et suscipit\n'
#          'suscipit recusandae consequuntur expedita et cum\n'
#          'reprehenderit molestiae ut ut quas totam\n'
#          'nostrum rerum est autem sunt rem eveniet architecto',
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}

# %%
import requests
url = "https://jsonplaceholder.typicode.com/posts"
payload = {"title": "test", "body" : "Hello API", "userID": 1}
response = requests.post(url, json = payload)
print(response.json())
# Out:
# {'title': 'test', 'body': 'Hello API', 'userID': 1, 'id': 101}

# %%
#open weather map ma gayera euta api दर्ता गर्नुहोस्
# what is rest and soap(simple object acess protocol)
#soap is only used in specific places only, eg -> banks

# %%
# !pip install zeep
# Out:
# ...
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 320.4 kB/s eta 0:00:00 kB/s eta 0:00:01
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 345.4 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...

# %%
from zeep import Client

wsdl = "http://www.dneonline.com/calculator.asmx?WSDL"
client = Client(wsdl = wsdl)

result = client.service.Add(10, 20)
print (result)
# Out:
# 30
