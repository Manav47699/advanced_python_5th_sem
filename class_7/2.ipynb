# %%
import pandas as pd

# %%
dictlsit = []
data44 = "manav"
data15= "janne"
for i in range(0, 100000):
    total_data = data44 + data15
    dictlsit.append(total_data)
df = pd.DataFrame(total_data)
dictlsit.to_csv("chunking.csv", index= False)

import tqdm
names = ["pam", "asda", "asdas"]
data_list =[]

for i in tqdm.tqdm(range(1, 100000)):
    data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       6     dictlsit.append(total_data)
#       7     # df = pd.DataFrame(total_data)
# ----> 8 dictlsit.to_csv("chunking.csv", index= False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
import tqdm
names = ["pam", "asda", "asdas", "Sita"]
data_list =[]

for i in tqdm.tqdm(range(1, 100000)):
    data

# %%
filename = "big_data.csv"
output_file = "output_data.csv"
first_chunk = True
for chunk in pd.read_csv(filename, chunksize= 10000):
    chunk["Gender"] = chunk["Name"].apply(lambda x:"Female" id x == "Sita" else "Male")
    print (chunk.head(5))
