# %% [markdown]
# # feature transformation, scaling and encoding

# %%
import numpy as np
x = np.array([1000, 222, 333, 444, 55, 66, 77,88])
x_transformed = np.log1p(x)
print(x_transformed)
# Out:
# [6.90875478 5.40717177 5.81114099 6.09807428 4.02535169 4.20469262
#  4.35670883 4.48863637]

# %%
import matplotlib.pyplot as plt
plt.hist(x_transformed)
# Out:
# (array([2., 2., 0., 0., 1., 0., 1., 1., 0., 1.]),
#  array([4.02535169, 4.313692  , 4.60203231, 4.89037262, 5.17871293,
#         5.46705324, 5.75539354, 6.04373385, 6.33207416, 6.62041447,
#         6.90875478]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x)
# Out:
# (array([4., 1., 1., 0., 1., 0., 0., 0., 0., 1.]),
#  array([  55. ,  149.5,  244. ,  338.5,  433. ,  527.5,  622. ,  716.5,
#          811. ,  905.5, 1000. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import  PowerTransformer
import numpy as np
x = np.array([1000, 222, 333, 444, 55, 66, 77,88])
pt = PowerTransformer(method="yeo-johnson")
x_transformed = np.log1p(x)
print(x_transformed)
