# %%
print ("hi")
# Out:
# hi

# %%
alist = [1, 2, 3, 4, 5]
iterator = iter(alist)
while True:
    try:
        num = next(iterator)
        print (num, end = ' ')
    except StopIteration:
        break
# Out:
# 1 2 3 4 5

# %% [markdown]
# # create a custom class iterator
#
# -> ans tala xa hai ta wow uwu

# %%
class CustomCounter:
    def __init__(self, limit):
        self.limit = limit
        self.current = 0
    
    def _iter_(self):
        return self
    
    def __next__(self):
        if self.current < self.limit:
            self.current += 1
            return self.current
    
        else:
            raise StopIteration
        


obj = CustomCounter(5)
for num in obj:
    print (num, end=' ')


#why error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 20
#      15             raise StopIteration
#      19 obj = CustomCounter(5)
# ---> 20 for num in obj:
#      21     print (num, end=' ')
#      24 #why error
#
# TypeError: 'CustomCounter' object is not iterable

# %%
def cubes(n):
    for i in range(n):
        yield i **3


for val in cubes(5):
    print (val)
# Out:
# 0
# 1
# 8
# 27
# 64

# %%
# %%timeit
for val in cubes(5):
    pass
# Out:
# 368 ns ± 0.314 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
cube_list = [val**3 for val in range(5)]
# Out:
# 313 ns ± 7.32 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print (f"calling function {func.__name__}")
        result = func(*args, **kwargs)
        print ("function completed")
        return result
    return wrapper

@logger
def add(a, b):
    return a+b

add(5, 4)
# Out:
# calling function add
# function completed
# 9

# %%
#write an iterator that retrun the first n even numbers


class EvenNumber:
    def __init__(self, nth_even_term):
        self.nth_even_term = nth_even_term
        self.current = 0
        self.count  =0
    
    def __iter__(self):
        return self
    
    def __next__(self):
        if self.count <= self.nth_even_term:
            self.current +=2
            self.count += 1
            return self.current   
        else:
            raise StopIteration
        


obj = EvenNumber(5)
for num in obj:
    print (num, end=' ')


#why error
# Out:
# 2 4 6 8 10 12

# %%
def fibo(n):
    a, b = 0, 1
    for i in range (n):
        yield a
        a, b = b, a + b

list(fibo(6))
# Out:
# [0, 1, 1, 2, 3, 5]
