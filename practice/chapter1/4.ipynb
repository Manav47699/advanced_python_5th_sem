# %% [markdown]
# # OOP for data science applications

# %% [markdown]
# # Inheritance

# %%
# parent class
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def bark(self):
        print (f"{self.name} says bhau bhau")

dog = Animal("Marco", 3)
dog.bark()

#child class
class Dog(Animal):
    def __init__(self, name, age, breed):
        super().__init__(name, age)
        self.breed = breed
    def dog_bark(self):
        print (f"{self.breed} {self.name} who is {self.age} years old says bhaubhau")

dog1= Dog("Marco", 3, "white dog")
dog1.dog_bark()
# Out:
# Marco says bhau bhau
# white dog Marco who is 3 years old says bhaubhau

# %% [markdown]
# # Operator Overloading
# -> It is a way of using signs in a way that it makes sense in your custom class

# %%
class Complex:
    def __init__(self, real, img):
        self.real =real
        self.img = img
    
    def __add__(self, other):
        r = self.real + other.real
        i = self.img + other.img
        return Complex(r, i)

# __str__ method: this method is used to decide what your object will look like when it is printed. It always returns an string
    def __str__(self):                           
        return f"{self.real} + {self.img}i"

a = Complex(3, 4)
b = Complex(1, 2)

c = a+ b
print (c)
# Out:
# 4 + 6i
