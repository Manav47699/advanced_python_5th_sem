# %% [markdown]
# # Reading and writing unstructured/structured data (CSV, JSON, Excel, text)
#
# - Structured data: They have a clear format and are usually tabluar. Eg: CSV, Excel, SQL tables
#
# - Unstructured data: Unstructured data has no predefined format. Eg: txt, logs
