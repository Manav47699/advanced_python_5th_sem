# %% [markdown]
# # Handling large datasets with chunking and lazy evaluation

# %% [markdown]
# # Lazy Evaluation

# %%
def read_lines(filename):
    with open(filename) as f:
        for line in f:
            yield line

for line in read_line("data.csv"):
    print (line)

# %% [markdown]
# # Chunking

# %%
import pandas as pd
import os

for chunk in pd.read_csv("data.csv", chunksize=4):
    print(chunk.head())
# Out:
#    Roll   Name Address  Salary       Date
# 0     1    Ram     BRT  1000.0  2026-1-24
# 1     4  ahanc     NaN  1000.0  2026-2-24
# 2     6  bhanc     BRT     NaN  2026-2-24
# 3     7  chanc     BRT  1000.0        NaN
#    Roll   Name   Address  Salary       Date
# 4     8  dhanc  kerabari  1000.0  2026-2-24
# 5    11    NaN       BRT     NaN  2026-1-24
# 6     3  ehanc       BRT  1000.0  2026-2-24
# 7    24    NaN       BRT  1000.0  2026-1-24
